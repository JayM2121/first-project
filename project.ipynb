# %% [markdown]
# https://github.com/JayM2121/first-project

# %% [markdown]
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# ## Описание проекта
#
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ## План решения задачи
#
# 1. Моя первая задача - промаркировать уровень финансовой активности постоянных покупателей. Я буду выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
# 2. Затем я соберу данные по клиентам по следующим группам:
# - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# Я представлю эти группы признаков (вместе с целевым) в виде диаграммы Исикавы. На диаграмме входные признаки будут объединены в четыре группы: коммуникация с клиентом, продуктовое поведение, поведение на сайте и финансовое поведение.
#
# 3. Следующим шагом будет построение модели, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
#
# 4. В исследование я включу дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
#
# 5. Используя данные модели и данные о прибыльности клиентов, я выделю сегменты покупателей и разработаю для них персонализированные предложения.
#
# Таким образом, я реализую описание решения, одобренное руководством, в качестве специалиста по DS.

# %% [markdown]
# ## Описание данных
#
# Данные для работы представлены в четырех таблицах:
#
# 1. **market_file.csv**: Таблица содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#     - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
#     - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#     - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев.
#     - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
#     - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#     - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#     - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
#     - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#     - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
#     - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
#     - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# 2. **market_money.csv**: Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#     - `Выручка` — сумма выручки за период.
#
# 3. **market_time.csv**: Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Период` — название периода, во время которого зафиксировано общее время.
#     - `минут` — значение времени, проведённого на сайте, в минутах.
#
# 4. **money.csv**: Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#     - `id` — номер покупателя в корпоративной базе данных.
#     - `Прибыль` — значение прибыли.

# %% [markdown]
# ## Основные этапы проекта
# **Этап 1: Разработка модели**
#
# Я начну с разработки модели, которая будет предсказывать вероятность снижения покупательской активности.
#
# **Этап 2: Анализ сегментов покупателей**
#
# Затем я выделю определенные сегменты покупателей, проанализирую их и предложу стратегии для увеличения их покупательской активности. Я буду использовать данные моделирования, данные о прибыли покупателей и исходные данные, если это будет необходимо. Я могу проанализировать более одного сегмента, если это будет целесообразно.
#
# Вот несколько примеров сегментов, которые я могу рассмотреть:
#
# - **Сегмент 1**: Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - **Сегмент 2**: Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - **Сегмент 3**: Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - **Сегмент 4**: Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.
#
#
# ## План выполнения проекта
#
# **Шаг 1: Загрузка данных**
#
# Я загружу данные из файлов `market_file.csv`, `market_money.csv`, `market_time.csv`, `money.csv`. Затем я проверю, что данные в таблицах соответствуют описанию.
#
# **Шаг 2: Предобработка данных**
#
# Я проведу необходимую предобработку данных.
#
# **Шаг 3: Исследовательский анализ данных**
#
# Я проведу исследовательский анализ данных из каждой таблицы. Я отберу клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.
#
# **Шаг 4: Объединение таблиц**
#
# Я объединю таблицы `market_file.csv`, `market_money.csv`, `market_time.csv`.
#
# **Шаг 5: Корреляционный анализ**
#
# Я проведу корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Я сделаю выводы о мультиколлинеарности и при необходимости устраню её.
#
# **Шаг 6: Использование пайплайнов**
#
# Я применю все изученные модели. Для этого я буду использовать пайплайны. Я обучу четыре модели: `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `LogisticRegression()` и `SVC()`. Для каждой из них я подберу как минимум один гиперпараметр.
#
# **Шаг 7: Анализ важности признаков**
#
# Я оценю важность признаков для лучшей модели и построю график важности с помощью метода SHAP.
#
# **Шаг 8: Сегментация покупателей**
#
# Я выполню сегментацию покупателей. Я использую результаты моделирования и данные о прибыли покупателей.
#
# **Шаг 9: Общий вывод**
#
# Я сделаю общий вывод, в котором опишу задачу, исходные данные и проведённую предобработку, укажу, что я сделал для поиска лучшей модели, укажу лучшую модель, добавлю выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1">Описание проекта</a></span></li><li><span><a href="#План-решения-задачи" data-toc-modified-id="План-решения-задачи-2">План решения задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3">Описание данных</a></span></li><li><span><a href="#Основные-этапы-проекта" data-toc-modified-id="Основные-этапы-проекта-4">Основные этапы проекта</a></span></li><li><span><a href="#План-выполнения-проекта" data-toc-modified-id="План-выполнения-проекта-5">План выполнения проекта</a></span></li><li><span><a href="#Иморт-библиотек" data-toc-modified-id="Иморт-библиотек-6">Иморт библиотек</a></span></li><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-7">Шаг 1. Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Шаг-1.2.-Проверка-соответствия-данных-описанию" data-toc-modified-id="Шаг-1.2.-Проверка-соответствия-данных-описанию-7.1">Шаг 1.2. Проверка соответствия данных описанию</a></span></li></ul></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-8">Шаг 2. Предобработка данных</a></span></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-9">Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#1.3.-Отберем-клиентов-с-покупательской-активностью-не-менее-трёх-месяцев,-то-есть-таких,-которые-что-либо-покупали-в-этот-период." data-toc-modified-id="1.3.-Отберем-клиентов-с-покупательской-активностью-не-менее-трёх-месяцев,-то-есть-таких,-которые-что-либо-покупали-в-этот-период.-9.1">1.3. Отберем клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.</a></span></li></ul></li><li><span><a href="#Шаг-4.-Объединение-таблиц" data-toc-modified-id="Шаг-4.-Объединение-таблиц-10">Шаг 4. Объединение таблиц</a></span><ul class="toc-item"><li><span><a href="#Шаг-4.1.-Объединение-таблиц-market_file,-market_money-и-market_time" data-toc-modified-id="Шаг-4.1.-Объединение-таблиц-market_file,-market_money-и-market_time-10.1">Шаг 4.1. Объединение таблиц market_file, market_money и market_time</a></span></li><li><span><a href="#Шаг-4.2.-Данные-о-выручке-и-времени-на-сайте-находятся-в-одном-столбце-для-всех-периодов.-В-итоговой-таблице-сделаем-отдельный-столбец-для-каждого-периода." data-toc-modified-id="Шаг-4.2.-Данные-о-выручке-и-времени-на-сайте-находятся-в-одном-столбце-для-всех-периодов.-В-итоговой-таблице-сделаем-отдельный-столбец-для-каждого-периода.-10.2">Шаг 4.2. Данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделаем отдельный столбец для каждого периода.</a></span></li></ul></li><li><span><a href="#Шаг-5.-Корреляционный-анализ" data-toc-modified-id="Шаг-5.-Корреляционный-анализ-11">Шаг 5. Корреляционный анализ</a></span></li><li><span><a href="#Шаг-6.-Использование-пайплайнов" data-toc-modified-id="Шаг-6.-Использование-пайплайнов-12">Шаг 6. Использование пайплайнов</a></span><ul class="toc-item"><li><span><a href="#Шаг-6.1.-Во-время-подготовки-данных-используем-ColumnTransformer.-Количественные-и-категориальные-признаки-обработаем-в-пайплайне-раздельно.-Для-кодирования-категориальных-признаков-используем-как-минимум-два-кодировщика,-для-масштабирования-количественных-—-как-минимум-два-скейлера." data-toc-modified-id="Шаг-6.1.-Во-время-подготовки-данных-используем-ColumnTransformer.-Количественные-и-категориальные-признаки-обработаем-в-пайплайне-раздельно.-Для-кодирования-категориальных-признаков-используем-как-минимум-два-кодировщика,-для-масштабирования-количественных-—-как-минимум-два-скейлера.-12.1">Шаг 6.1. Во время подготовки данных используем ColumnTransformer. Количественные и категориальные признаки обработаем в пайплайне раздельно. Для кодирования категориальных признаков используем как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.</a></span></li></ul></li><li><span><a href="#Шаг-7.-Анализ-важности-признаков" data-toc-modified-id="Шаг-7.-Анализ-важности-признаков-13">Шаг 7. Анализ важности признаков</a></span><ul class="toc-item"><li><span><a href="#Шаг-7.1.-Оценим-важность-признаков-для-лучшей-модели-и-построим-график-важности-с-помощью-метода-SHAP." data-toc-modified-id="Шаг-7.1.-Оценим-важность-признаков-для-лучшей-модели-и-построим-график-важности-с-помощью-метода-SHAP.-13.1">Шаг 7.1. Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP.</a></span></li><li><span><a href="#Шаг-7.2.-Сделаем-выводы-о-значимости-признаков:" data-toc-modified-id="Шаг-7.2.-Сделаем-выводы-о-значимости-признаков:-13.2">Шаг 7.2. Сделаем выводы о значимости признаков:</a></span></li></ul></li><li><span><a href="#Шаг-8.-Сегментация-покупателей" data-toc-modified-id="Шаг-8.-Сегментация-покупателей-14">Шаг 8. Сегментация покупателей</a></span><ul class="toc-item"><li><span><a href="#Шаг-8.1.--Выполним-сегментацию-покупателей.-Используем-результаты-моделирования-и-данные-о-прибыльности-покупателей." data-toc-modified-id="Шаг-8.1.--Выполним-сегментацию-покупателей.-Используем-результаты-моделирования-и-данные-о-прибыльности-покупателей.-14.1">Шаг 8.1.  Выполним сегментацию покупателей. Используем результаты моделирования и данные о прибыльности покупателей.</a></span></li><li><span><a href="#Шаг-8.2.-Выберем-группу-покупателей-и-предложим,-как-увеличить-её-покупательскую-активность:" data-toc-modified-id="Шаг-8.2.-Выберем-группу-покупателей-и-предложим,-как-увеличить-её-покупательскую-активность:-14.2">Шаг 8.2. Выберем группу покупателей и предложим, как увеличить её покупательскую активность:</a></span></li><li><span><a href="#Шаг-8.3.-Сделаем-выводы-о-сегментах:" data-toc-modified-id="Шаг-8.3.-Сделаем-выводы-о-сегментах:-14.3">Шаг 8.3. Сделаем выводы о сегментах:</a></span></li></ul></li><li><span><a href="#Шаг-9.-Общий-вывод" data-toc-modified-id="Шаг-9.-Общий-вывод-15">Шаг 9. Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Иморт библиотек

# %%
# Устанавливаем библиотеку phik
# !pip install phik -q
# Устанавливаем библиотеку shap
# !pip install shap -q
# Устанавливаем библиотеку mlxtend
# !pip install mlxtend -q

# %%
# Импортируем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import math
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix, classification_report, precision_recall_curve
from sklearn.cluster import KMeans
import phik
import shap

# Импортируем дополнительные библиотеки
import matplotlib.ticker as mtick

# Устанавливаем стиль и цветовую палитру для графиков
sns.set_style('whitegrid')
sns.set_palette('pastel')

# %%
TEST_SIZE = 0.2 
RANDOM_STATE = 42

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
# Загрузка данных
market_file = pd.read_csv('/datasets/market_file.csv')
market_money = pd.read_csv('/datasets/market_money.csv')
market_time = pd.read_csv('/datasets/market_time.csv')
money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

# Проверка загруженных данных
print('Данные market_file:')
display(market_file.head())
print('\nДанные market_money:')
display(market_money.head())
print('\nДанные market_time:')
display(market_time.head())
print('\nДанные money:')
display(money.head())
# Out:
# Данные market_file:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# ### Шаг 1.2. Проверка соответствия данных описанию

# %%
# Проверка структуры и типов данных в таблицах
print("Структура и типы данных в market_file:")
market_file.info()
print("\nСтруктура и типы данных в market_money:")
market_money.info()
print("\nСтруктура и типы данных в market_time:")
market_time.info()
print("\nСтруктура и типы данных в money:")
money.info()
# Out:
# Структура и типы данных в market_file:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
# ...

# %% [markdown]
# **1. Проверка типов данных:**
#
# * Все столбцы в таблицах имеют типы данных, соответствующие их описанию.
#     * `id` во всех таблицах - целочисленный тип данных.
#     * В таблице `market_file` столбцы `Маркет_актив_6_мес`, `Акционные_покупки`, `Средний_просмотр_категорий_за_визит`, `Неоплаченные_продукты_штук_квартал`, `Ошибка_сервиса`, `Страниц_за_визит` - вещественный тип данных.
#     * В таблицах `market_money` и `money` столбцы `Выручка` и `Прибыль` - вещественный тип данных.
#     * Во всех таблицах остальные столбцы - текстовый тип данных.
# * Количество строк в таблицах:
#     * `market_file` - 1300 строк
#     * `market_money` - 3900 строк
#     * `market_time` - 2600 строк
#     * `money` - 1300 строк
#
# **2. Проверка уникальности значений:**
#
# * В столбце `id` всех таблиц значения должны быть уникальными.
# * В столбце `Период` таблицы `market_money` значения должны соответствовать описанию: 'текущий_месяц', 'предыдущий_месяц', 'препредыдущий_месяц'.
# * В столбце `Популярная_категория` таблицы `market_file` значения должны соответствовать названиям категорий товаров.
# * В столбце `Тип сервиса` таблицы `market_file` значения должны быть 'премиум' или 'стандарт'.
# * В столбце `Разрешить сообщать` таблицы `market_file` значения должны быть 'да' или 'нет'.

# %% [markdown]
# **Шаг 1: Загрузка и проверка данных**
#
# В этом шаге мы успешно загрузили данные из четырех различных CSV-файлов: `market_file.csv`, `market_money.csv`, `market_time.csv` и `money.csv`.
#
# Данные в `market_file` содержат информацию о покупательской активности, типе сервиса, разрешении на сообщения, активности на рынке, длительности, акционных покупках, популярных категориях, среднем просмотре категорий за визит, неоплаченных продуктах и ошибках сервиса.
#
# `market_money` содержит данные о выручке за разные периоды, `market_time` содержит информацию о времени, проведенном пользователями, а `money` содержит данные о прибыли.
#
# Мы проверили структуру и типы данных в каждом из этих наборов данных. Все данные были корректными и не требовали дополнительной обработки.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
dataframes = [market_file, market_money, market_time, money]
df_names = ['market_file', 'market_money', 'market_time', 'money']

# %% [markdown]
# **1. Проверка на дубликаты**

# %%
# Проверка на дубликаты
for df, name in zip(dataframes, df_names):
    print(f"Количество дубликатов в {name}:", df.duplicated().sum())
# Out:
# Количество дубликатов в market_file: 0
# Количество дубликатов в market_money: 0
# Количество дубликатов в market_time: 0
# Количество дубликатов в money: 0

# %% [markdown]
# **2. Проверка на пропущенные значения**

# %%
# Проверка на пропущенные значения
for df, name in zip(dataframes, df_names):
    print(f"\nКоличество пропущенных значений в {name}:")
    print(df.isnull().sum())
# Out:
# Количество пропущенных значений в market_file:
# id                                     0
# Покупательская активность              0
# Тип сервиса                            0
# Разрешить сообщать                     0
# Маркет_актив_6_мес                     0
# Маркет_актив_тек_мес                   0
# Длительность                           0
# Акционные_покупки                      0
# Популярная_категория                   0
# Средний_просмотр_категорий_за_визит    0
# Неоплаченные_продукты_штук_квартал     0
# Ошибка_сервиса                         0
# Страниц_за_визит                       0
# dtype: int64
#
# Количество пропущенных значений в market_money:
# id         0
# Период     0
# Выручка    0
# dtype: int64
#
# Количество пропущенных значений в market_time:
# id        0
# Период    0
# минут     0
# dtype: int64
#
# Количество пропущенных значений в money:
# id         0
# Прибыль    0
# dtype: int64

# %% [markdown]
# **3. Проверим уникальные значения в столбцах с категориальными данными. Переименуем столбцы, приведем к общему виду**

# %%
# Проверка уникальных значений в столбцах с категориальными данными
for df in dataframes:
    for column in df.columns:
        if df[column].dtype == 'object':
            print(f'\nУникальные значения в столбце {column}:')
            print(df[column].unique())
# Out:
# Уникальные значения в столбце Покупательская активность:
# ['Снизилась' 'Прежний уровень']
#
# Уникальные значения в столбце Тип сервиса:
# ['премиум' 'стандартт' 'стандарт']
#
# Уникальные значения в столбце Разрешить сообщать:
# ['да' 'нет']
#
# Уникальные значения в столбце Популярная_категория:
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
#
# Уникальные значения в столбце Период:
# ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
#
# Уникальные значения в столбце Период:
# ['текущий_месяц' 'предыдцщий_месяц']

# %%
# Приведение названий столбцов к одному виду
for df in dataframes:
    df.columns = df.columns.str.lower().str.replace(' ', '_')

# Проверка результатов
for df, name in zip(dataframes, df_names):
    print(f'\nСтолбцы в {name} после приведения к одному виду:')
    print(df.columns)
# Out:
# Столбцы в market_file после приведения к одному виду:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')
#
# Столбцы в market_money после приведения к одному виду:
# Index(['id', 'период', 'выручка'], dtype='object')
#
# Столбцы в market_time после приведения к одному виду:
# Index(['id', 'период', 'минут'], dtype='object')
#
# Столбцы в money после приведения к одному виду:
# Index(['id', 'прибыль'], dtype='object')

# %%
# Исправление ошибок в данных
market_file['тип_сервиса'] = market_file['тип_сервиса'].replace('стандартт', 'стандарт')
market_time['период'] = market_time['период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

# Проверка уникальных значений во всех категориальных столбцах после исправления
for df in dataframes:
    for column in df.columns:
        if df[column].dtype == 'object':
            print(f'\nУникальные значения в столбце {column} после исправления:')
            print(df[column].unique())
# Out:
# Уникальные значения в столбце покупательская_активность после исправления:
# ['Снизилась' 'Прежний уровень']
#
# Уникальные значения в столбце тип_сервиса после исправления:
# ['премиум' 'стандарт']
#
# Уникальные значения в столбце разрешить_сообщать после исправления:
# ['да' 'нет']
#
# Уникальные значения в столбце популярная_категория после исправления:
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']
#
# Уникальные значения в столбце период после исправления:
# ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']
#
# Уникальные значения в столбце период после исправления:
# ['текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# **4. Проверка целостности данных**
#
# * В столбцах `Маркет_актив_6_мес`, `Акционные_покупки`, `Средний_просмотр_категорий_за_визит`, `Неоплаченные_продукты_штук_квартал`, `Ошибка_сервиса`, `Страниц_за_визит`, `Выручка`, `Прибыль` значения не должны быть отрицательными.
# * В столбце `Длительность` таблицы `market_file` значения должны быть больше 0.
# * В столбце `минут` таблицы `market_time` значения должны быть больше 0.

# %%
# Список столбцов, которые должны содержать только положительные значения
columns_to_check_market_file = ['маркет_актив_6_мес', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 
                    'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит']
columns_to_check_market_money = ['выручка']
columns_to_check_money = ['прибыль']

# Проверка на отрицательные значения
for column in columns_to_check_market_file:
    if (market_file[column] < 0).any():
        print(f"\nСтолбец {column} содержит отрицательные значения.")
    else:
        print(f"\nСтолбец {column} не содержит отрицательных значений.")

for column in columns_to_check_market_money:
    if (market_money[column] < 0).any():
        print(f"\nСтолбец {column} содержит отрицательные значения.")
    else:
        print(f"\nСтолбец {column} не содержит отрицательных значений.")

for column in columns_to_check_money:
    if (money[column] < 0).any():
        print(f"\nСтолбец {column} содержит отрицательные значения.")
    else:
        print(f"\nСтолбец {column} не содержит отрицательных значений.")
# Out:
# Столбец маркет_актив_6_мес не содержит отрицательных значений.
#
# Столбец акционные_покупки не содержит отрицательных значений.
#
# Столбец средний_просмотр_категорий_за_визит не содержит отрицательных значений.
#
# Столбец неоплаченные_продукты_штук_квартал не содержит отрицательных значений.
#
# Столбец ошибка_сервиса не содержит отрицательных значений.
#
# Столбец страниц_за_визит не содержит отрицательных значений.
#
# Столбец выручка не содержит отрицательных значений.
#
# Столбец прибыль не содержит отрицательных значений.

# %% [markdown]
# **Шаг 2: Предобработка данных**
#
# В ходе предобработки данных были выполнены следующие шаги:
#
# - **Проверка на дубликаты**: Все датафреймы (`market_file`, `market_money`, `market_time`, `money`) были проверены на наличие дубликатов. В результате проверки было обнаружено, что дубликатов нет.
#
# - **Проверка на пропущенные значения**: Все датафреймы были проверены на наличие пропущенных значений. В результате проверки было обнаружено, что пропущенных значений нет.
#
# - **Проверка уникальных значений в столбцах с категориальными данными**: Были проверены уникальные значения во всех категориальных столбцах. Были обнаружены некоторые ошибки в данных, которые были исправлены. Например, в столбце 'Тип сервиса' датафрейма `market_file` значение 'стандартт' было заменено на 'стандарт', а в столбце 'Период' датафрейма `market_time` значение 'предыдцщий_месяц' было заменено на 'предыдущий_месяц'.
# - **Приведение названий столбцов к одному виду**: Названия столбцов всех датафреймов были приведены к нижнему регистру и заменены пробелы на подчеркивания для удобства работы с данными.
#
# - **Проверка целостности данных**: Была проведена проверка на отрицательные значения в столбцах, которые должны содержать только положительные значения. В результате проверки было обнаружено, что отрицательных значений нет.
#
# В результате предобработки данных все датафреймы были подготовлены для дальнейшего анализа. Данные оказались достаточно чистыми, и было обнаружено лишь небольшое количество ошибок, которые были успешно исправлены. Это позволит провести более точный и эффективный анализ данных на следующих этапах проекта.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# **1. Проведем статистический анализ всех признаков. Построим графики для каждого признака.  Сделаем выводы о данных.**

# %%
# Функция для построения гистограммы и диаграммы размаха для столбцов с количественными признаками
def hist_box(data, column):
    fig, ax = plt.subplots(1, 3, figsize=(20, 8))
    
    # Гистограмма 
    sns.histplot(data[column], kde=True, ax=ax[0])
    ax[0].set_title(f'Гистограмма "{column}"')
    ax[0].set_xlabel(f'Значения столбца "{column}"')
    ax[0].set_ylabel('Частота')
    
    # Диаграмма размаха
    sns.boxplot(x=data[column], ax=ax[1])
    ax[1].set_title(f'Диаграмма размаха для "{column}"')
    ax[1].set_xlabel(f'Значения столбца "{column}"')
    
    # Виолончельная диаграмма
    sns.violinplot(x=data[column], ax=ax[2])
    ax[2].set_title(f'Виолончельная диаграмма для "{column}"')
    ax[2].set_xlabel(f'Значения столбца "{column}"')
    
    # Функция для визуализации категориальных признаков
def cat_func(data):
    for column in data.columns:
        plt.figure(figsize=(10, 6))
        counts = data[column].value_counts()
        labels = counts.index
        plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
        plt.title(f'Распределение для "{column}"')
        plt.show()

# %% [markdown]
# **Анализ датафрейма `market_file`**

# %%
# Описательная статистика для market_file, исключая столбец id
market_file.loc[:, market_file.columns != 'id'].describe()
# Out:
#        маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count         1300.000000           1300.000000   1300.000000
# mean             4.253769              4.011538    601.898462
# std              1.014814              0.696868    249.856289
# min              0.900000              3.000000    110.000000
# 25%              3.700000              4.000000    405.500000
# 50%              4.200000              4.000000    606.000000
# 75%              4.900000              4.000000    806.000000
# max              6.600000              5.000000   1079.000000
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# min             0.000000                              1.00000
# 25%             0.170000                              2.00000
# ...

# %%
# Создаём DataFrame, содержащий только числовые столбцы market_file (без id)
market_file_num = market_file.select_dtypes(include='number').drop(['id'], axis=1)

# %%
for name in market_file_num.columns:
    hist_box(market_file, name)

# %%
# Создание DataFrame с категориальными столбцами
market_file_cat = market_file.select_dtypes(include='object')

# %%
# Применение функции к категориальным данным
cat_func(market_file_cat)

# %%
# Вывод описательной статистики для каждого категориального столбца
for column in market_file_cat.columns:
    print(f'Описательная статистика для "{column}":')
    display(market_file_cat[column].value_counts())
# Out:
# Описательная статистика для "покупательская_активность":
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
# Описательная статистика для "тип_сервиса":
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64
# Описательная статистика для "разрешить_сообщать":
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64
# Описательная статистика для "популярная_категория":
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %% [markdown]
# **Числовые столбцы:**
# - Длительность среднего использования на платформе составляет примерно 601.9 дней, с минимальным значением 110 дней и максимальным значением 1079 дней.
# - Среднее количество маркетинговых активов за последние 6 месяцев составляет около 4.25, с минимальным значением около 0.9 и максимальным около 6.6.
# - Среднее количество акционных покупок составляет около 0.32, с минимальным значением 0 и максимальным значением 0.99.
#
# **Категориальные столбцы:**
# - Большинство пользователей имеют прежний уровень покупательской активности (802 человека), однако у 498 пользователей наблюдается снижение активности.
# - Большинство пользователей пользуются стандартным типом сервиса (924 человека), в то время как премиум-сервисом пользуются 376 человек.
# - Большинство пользователей разрешают отправку уведомлений (962 человека), но также есть и те, кто отказывается (338 человек).
# - Среди популярных категорий товаров на платформе наиболее популярными являются "Товары для детей", "Домашний текстиль" и "Косметика и аксессуары".
#
# **Вывод:**
# 1. Большинство пользователей предпочитают стандартный тип сервиса и разрешают отправку уведомлений.
# 2. Наблюдается разнообразие в популярных категориях товаров, что может говорить о широком спектре интересов пользователей.
# 3. Падение покупательской активности у значительной части пользователей может быть предметом дополнительного анализа для выявления причин и принятия соответствующих мер.

# %% [markdown]
# **Анализ датафрейма `market_money`**

# %%
# Описательная статистика для market_file, исключая столбец id
market_money.loc[:, market_money.columns != 'id'].describe()
# Out:
#              выручка
# count    3900.000000
# mean     5025.696051
# std      1777.704104
# min         0.000000
# 25%      4590.150000
# 50%      4957.500000
# 75%      5363.000000
# max    106862.200000

# %%
# Создаём DataFrame, содержащий только числовые столбцы market_file (без id)
market_money_num = market_money.select_dtypes(include='number').drop(['id'], axis=1)

# %%
for name in market_money_num.columns:
    hist_box(market_money, name)

# %%
# Создаем переменную без аномальны значений выручки
market_money = market_money.query('0 < выручка < 106862.2')

# Построение распределений количественных признаков датасета без выбросов
for name in market_money_num.columns:
    hist_box(market_money, name)

# %%
# Создание DataFrame с категориальными столбцами
market_money_cat = market_money.select_dtypes(include='object')

# Применение функции к категориальным данным
cat_func(market_money_cat)

# Вывод описательной статистики для каждого категориального столбца
for column in market_money_cat.columns:
    print(f'Описательная статистика для "{column}":')
    display(market_money_cat[column].value_counts())
# Out:
# Описательная статистика для "период":
# текущий_месяц          1299
# предыдущий_месяц       1297
# препредыдущий_месяц    1297
# Name: период, dtype: int64

# %% [markdown]
# **Выбросы:**
#
# - Обнаружен один выброс в столбце "выручка" - значение 106862.20.
# - Выброс был удален из датафрейма.
# - Распределения выглядят более однородными, чем до удаления выброса.
#
# **Выводы:**
#
# - В целом, данные имеют нормальное распределение, за исключением столбца "выручка", где был обнаружен выброс.
# - Выброс был удален, что сделало распределения более однородными.

# %% [markdown]
# **Анализ датафрейма `market_time`**

# %%
# Описательная статистика для market_time, исключая столбец id
market_time.loc[:, market_time.columns != 'id'].describe()
# Out:
#              минут
# count  2600.000000
# mean     13.336154
# std       4.080198
# min       4.000000
# 25%      10.000000
# 50%      13.000000
# 75%      16.000000
# max      23.000000

# %%
# Создаём DataFrame, содержащий только числовые столбцы market_time (без id)
market_time_num = market_time.select_dtypes(include='number').drop(['id'], axis=1)

# %%
for name in market_time_num.columns:
    hist_box(market_time, name)

# %%
# Создание DataFrame с категориальными столбцами
market_time_cat = market_time.select_dtypes(include='object')

# Применение функции к категориальным данным
cat_func(market_time_cat)

# Вывод описательной статистики для каждого категориального столбца
for column in market_time_cat.columns:
    print(f'Описательная статистика для "{column}":')
    display(market_time_cat[column].value_counts())
# Out:
# Описательная статистика для "период":
# предыдущий_месяц    1300
# текущий_месяц       1300
# Name: период, dtype: int64

# %% [markdown]
# **Выводы:**
#
# - В целом, данные имеют нормальное распределение.
# - "Текущий_месяц" и "Предыдущий_месяц" представлены в равном количестве.
# - Среднее время, проведенное на сайте, составляет около 13 минут.

# %% [markdown]
# **Анализ датафрейма `money`**

# %%
# Описательная статистика для money, исключая столбец id
money.loc[:, money.columns != 'id'].describe()
# Out:
#            прибыль
# count  1300.000000
# mean      3.996631
# std       1.013722
# min       0.860000
# 25%       3.300000
# 50%       4.045000
# 75%       4.670000
# max       7.430000

# %%
# Создаём DataFrame, содержащий только числовые столбцы money (без id)
money_num = money.select_dtypes(include='number').drop(['id'], axis=1)

# %%
for name in money_num.columns:
    hist_box(money, name)

# %% [markdown]
# **Выводы:**
#
# - В целом, данные имеют нормальное распределение.
# - Средняя прибыль составляет около 4.00.

# %% [markdown]
# ### 1.3. Отберем клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.

# %%
# Определение активных клиентов
active_clients = market_money.groupby('id').filter(lambda x: x['период'].nunique() == 3)

# Получение списка активных клиентов
active_clients_ids = active_clients['id'].unique()

# Фильтрация данных по активным клиентам в каждом датасете
market_file = market_file[market_file['id'].isin(active_clients_ids)]
market_money = market_money[market_money['id'].isin(active_clients_ids)]
market_time = market_time[market_time['id'].isin(active_clients_ids)]
money = money[money['id'].isin(active_clients_ids)]

print('market_file' ,market_file.shape[0])
print('market_money', market_money.shape[0])
print('market_time', market_time.shape[0])
print('money', money.shape[0])
# Out:
# market_file 1296
# market_money 3888
# market_time 2592
# money 1296

# %% [markdown]
# **Выводы:**
#
# * Данные в целом имеют хорошее качество, за исключением некоторых выбросов, которые были удалены.
# * Распределения большинства числовых признаков близки к нормальному.

# %% [markdown]
# **Шаг 3: Исследовательский анализ данных**
#
# В ходе исследовательского анализа были изучены данные из четырех датафреймов: `market_file`, `market_money`, `market_time` и `money`. Для каждого датафрейма были проведены следующие шаги:
#
# 1. **Статистический анализ признаков**: была получена описательная статистика для каждого признака, включая среднее значение, медиану, минимальное и максимальное значения, а также стандартное отклонение.
#
# 2. **Визуализация данных**: для каждого признака были построены гистограммы, диаграммы размаха и виолончельные диаграммы. Для категориальных признаков были построены диаграммы распределения.
#
# 3. **Анализ выбросов**: были обнаружены и удалены выбросы в некоторых числовых столбцах, что сделало распределения более однородными.
#
# 4. **Отбор активных клиентов**: были отобраны клиенты с покупательской активностью не менее трёх месяцев.
#
# В целом, данные в датафреймах имеют хорошее качество и нормальное распределение, что делает их подходящими для дальнейшего анализа и моделирования.

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %% [markdown]
# ### Шаг 4.1. Объединение таблиц market_file, market_money и market_time

# %% [markdown]
# ### Шаг 4.2. Данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделаем отдельный столбец для каждого периода.

# %%
# Создание сводных таблиц для выручки и времени
market_money_grouped = market_money.pivot_table(index='id', columns='период', values='выручка')
market_money_grouped.columns = ['выручка_' + col for col in market_money_grouped.columns]

market_time_grouped = market_time.pivot_table(index='id', columns='период', values='минут')
market_time_grouped.columns = ['минут_' + col for col in market_time_grouped.columns]

# Объединение таблиц и создание итоговой таблицы
market_fin = market_file.merge(market_money_grouped, on='id').merge(market_time_grouped, on='id')

# Проверка на количество строк
original_rows = len(market_file)
merged_rows = len(market_fin)
if merged_rows != original_rows:
    print(f"Внимание: количество строк после объединения таблиц изменилось. Исходное количество строк: {original_rows}, количество строк после объединения: {merged_rows}")

# Просмотр первых 5 строк получившегося датафрейма
market_fin.head(5)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# **Шаг 4. Объединение таблиц**
#
# На этом шаге было выполнено объединение трех таблиц: `market_file`, `market_money` и `market_time`. Для этого были использованы методы `pivot_table` и `merge` библиотеки pandas.
#
# Сначала были созданы сводные таблицы для `market_money` и `market_time`, где каждый период был преобразован в отдельный столбец. Это позволило нам иметь отдельные столбцы для выручки и времени на сайте для каждого периода.
#
# Затем эти сводные таблицы были объединены с основной таблицей `market_file` по столбцу 'id'. Результатом является итоговая таблица `market_fin`, которая содержит все необходимые данные в удобном для анализа формате.

# %% [markdown]
# ## Шаг 5. Корреляционный анализ
# Проведем корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделаем выводы о мультиколлинеарности и при необходимости устраним её.

# %%
# Вычисление корреляции с использованием phik
correlation_matrix = market_fin.drop('id', axis=1).phik_matrix()

# Визуализация матрицы корреляции
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=.5, cmap='cividis', vmin=0, vmax=1)
plt.title(r'Корреляция $\phi_K$', fontsize=18)
plt.show()
# Out:
# interval columns not set, guessing: ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц', 'минут_предыдущий_месяц', 'минут_текущий_месяц']

# %% [markdown]
# Наиболее сильные корреляции наблюдаются между следующими парами признаков:
# - 'выручка_предыдущий_месяц' и 'выручка_текущий_месяц' (0.84)
# - 'покупательская_активность' и 'страниц_за_визит' (0.75)
# - 'покупательская_активность' и 'минут_предыдущий_месяц' (0.69)

# %% [markdown]
# **Шаг 5. Корреляционный анализ**
#
# Корреляционный анализ позволяет нам оценить взаимосвязи между различными признаками в нашем наборе данных. Важно отметить, что корреляция не подразумевает причинно-следственную связь, но может указывать на наличие таковой.
#
# Мультиколлинеарность, которая обозначает высокую корреляцию между двумя или более входными признаками, может привести к проблемам в моделировании, так как она затрудняет определение влияния отдельных признаков на целевую переменную. **Однако, в нашем случае, мультиколлинеарность не является проблемой, так как коэффициенты корреляции между признаками не достигают критического уровня (обычно 0.9 или выше).**

# %% [markdown]
# ## Шаг 6. Использование пайплайнов

# %% [markdown]
# ### Шаг 6.1. Во время подготовки данных используем ColumnTransformer. Количественные и категориальные признаки обработаем в пайплайне раздельно. Для кодирования категориальных признаков используем как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.

# %% [markdown]
# Преобразуем категориальный признак ‘покупательская_активность’ в числовой, чтобы модель машинного обучения могла работать с этим признаком Если активность покупателя ‘Снизилась’, то она преобразуется в 1, в противном случае - в 0.
#
# Создадим новый категориальный признак ‘акционные_покупки_категория’ на основе числового признака ‘акционные_покупки’. Если значение ‘акционные_покупки’ больше или равно 0.5, то новый признак получает значение ‘Часто покупает по акции’, в противном случае - ‘Редко покупает по акции’. Это может помочь модели лучше понять взаимосвязи в данных.

# %%
market_fin['покупательская_активность'] = \
    market_fin['покупательская_активность'].apply(lambda x: 1 if x=='Снизилась' else 0).astype(int)

market_fin['акционные_покупки_категория'] = \
    market_fin['акционные_покупки'].apply(lambda x: 'Часто покупает по акции' if x>= 0.5 else 'Редко покупает по акции')

# Eдаляем столбец ‘акционные_покупки’ из нашего датафрейма, так как мы уже использовали эту информацию для создания нового 
# признака ‘акционные_покупки_категория’.
market_fin = market_fin.drop(['акционные_покупки'], axis=1).set_index('id')

# %%
# Разделение данных на обучающую и тестовую выборки
X = market_fin.drop(['покупательская_активность'], axis=1)
y = market_fin['покупательская_активность']
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y)

# Определение категорий признаков
ohe_columns = ['разрешить_сообщать', 'популярная_категория', 'тип_сервиса']
ord_columns = ['акционные_покупки_категория']
num_columns = [
    'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'маркет_актив_тек_мес', 
    'длительность', 'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 
    'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц', 
    'минут_предыдущий_месяц', 'минут_текущий_месяц'
]

# Создание пайплайнов для обработки признаков
ohe_pipe = Pipeline([
    ('simpleImputer_ohe', SimpleImputer(strategy='most_frequent')), 
    ('ohe', OneHotEncoder())
])

ord_pipe = Pipeline([
    ('simple_imputer_ord_before', SimpleImputer(strategy='most_frequent')),
    ('ord', OrdinalEncoder(categories=[['Редко покупает по акции','Часто покупает по акции']], 
                           handle_unknown='use_encoded_value', unknown_value=np.nan)),
    ('simple_imputer_ord_after', SimpleImputer(strategy='most_frequent'))
])

# Создание конечного пайплайна
data_preprocessor = ColumnTransformer([
    ('ohe', ohe_pipe, ohe_columns), 
    ('ord', ord_pipe, ord_columns), 
    ('num', MinMaxScaler(), num_columns)
], remainder='passthrough')

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor), 
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)], 
        'models__max_depth': range(2, 7), 
        'models__max_features': range(2,7), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [KNeighborsClassifier()], 
        'models__n_neighbors': range(2,5), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', penalty='l1')], 
        'models__C': range(1,5), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [SVC(random_state=RANDOM_STATE, kernel='poly')], 
        'models__degree': range(2, 3), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
        'models__random_state': [RANDOM_STATE]
    }
]

# %%
# Поиск лучшей модели
randomized_search = RandomizedSearchCV(pipe_final, param_grid, cv=5, scoring='roc_auc', random_state=RANDOM_STATE, n_jobs=-1)
randomized_search.fit(X_train, y_train)

# Вывод результатов
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', round(randomized_search.best_score_, 2))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder())]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория',
#                                                    'тип_сервиса']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simple_imputer_ord_before',
# ...

# %%
# Проверка модели на тестовой выборке
y_test_pred = randomized_search.predict(X_test)
y_test_proba = randomized_search.predict_proba(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test, y_test_proba[:,1]), 2)}')
print(f'Метрика F1-score на тестовой выборке: {round(f1_score(y_test, y_test_pred, average="macro"), 2)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.91
# Метрика F1-score на тестовой выборке: 0.89

# %% [markdown]
# **Поиск лучшей модели**: Используем GridSearchCV для перебора заданных параметров модели и выбора наилучшей модели с использованием кросс-валидации. Этот процесс поможет нам определить наилучшие параметры модели, которые обеспечивают наилучшую производительность на тренировочном наборе данных.

# %%
# Поиск лучшей модели с использованием GridSearchCV
grid_search = GridSearchCV(pipe_final, param_grid, cv=5, scoring='roc_auc', n_jobs=-1)
grid_search.fit(X_train, y_train)

# Вывод результатов
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print('Метрика ROC-AUC на тренировочной выборке:', round(grid_search.best_score_, 2))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder())]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория',
#                                                    'тип_сервиса']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simple_imputer_ord_before',
# ...

# %% [markdown]
# **Оценка производительности**: После выбора лучшей модели мы оцениваем ее производительность на тестовой выборке, используя метрики ROC-AUC и F1-score. ROC-AUC - это показатель, который измеряет качество бинарной классификации, а F1-score - среднее гармоническое между точностью и полнотой. Эти метрики помогают нам понять, насколько хорошо модель работает на невидимых данных.

# %%
# Оценка результатов на тестовой выборке
y_test_pred = grid_search.predict(X_test)
y_test_proba = grid_search.predict_proba(X_test)
roc_auc = round(roc_auc_score(y_test, y_test_proba[:,1]), 2)
f1 = round(f1_score(y_test, y_test_pred, average='macro'), 2)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc}')
print(f'Метрика F1-score на тестовой выборке: {f1}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.91
# Метрика F1-score на тестовой выборке: 0.9

# %% [markdown]
# **Анализ ошибок модели**: Мы также анализируем ошибки модели, строим матрицу ошибок и выводим отчет о классификации на тестовой выборке. Эти метрики позволяют нам понять, какие классы модель предсказывает правильно, а в каких случаях допускает ошибки.

# %%
# Анализ ошибок модели
conf_matrix = confusion_matrix(y_test, y_test_pred)
print('Матрица ошибок на тестовой выборке:\n', conf_matrix)
print('Отчет о классификации на тестовой выборке:\n', classification_report(y_test, y_test_pred))
# Out:
# Матрица ошибок на тестовой выборке:
#  [[153   8]
#  [ 17  82]]
# Отчет о классификации на тестовой выборке:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       161
#            1       0.91      0.83      0.87        99
#
#     accuracy                           0.90       260
#    macro avg       0.91      0.89      0.90       260
# weighted avg       0.90      0.90      0.90       260

# %% [markdown]
# **Построение кривой precision-recall**: Дополнительно строим кривую precision-recall, которая позволяет оценить производительность модели при различных порогах вероятности классификации. Это полезно для понимания, как изменения порога влияют на точность и полноту модели.

# %%
# Построение кривой precision-recall
precision, recall, _ = precision_recall_curve(y_test, y_test_proba[:,1])

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Полнота')
plt.ylabel('Точность')
plt.title('Кривая Precision-Recall')
plt.grid(True)
plt.show()

# %% [markdown]
# **Шаг 6. Построение модели, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.**
#
# В этом шаге мы использовали ColumnTransformer для обработки категориальных и количественных признаков раздельно. Мы кодировали категориальные признаки с помощью OneHotEncoder и OrdinalEncoder, а количественные признаки масштабировали с помощью StandardScaler и MinMaxScaler.
#
# 1. **Выбор модели**: Было проведено сравнение нескольких моделей машинного обучения, включая Decision Tree, K-Nearest Neighbors, Logistic Regression и Support Vector Classifier. Использовался процесс подбора оптимальных гиперпараметров для каждой модели с помощью GridSearchCV.
#
# 2. **Лучшая модель**: Наилучшей моделью, оцененной с помощью метрики ROC-AUC на тренировочной выборке, оказалась логистическая регрессия (Logistic Regression). Это означает, что логистическая регрессия имеет наилучшую способность разделять классы на тренировочных данных, что является важным показателем для эффективной классификации клиентов по их покупательской активности.
#
# 3. **Оценка производительности**: Выбранная модель была оценена на тестовой выборке с использованием метрик ROC-AUC и F1-score. ROC-AUC показало значение 0.91, что свидетельствует о хорошем качестве модели в разделении классов. F1-score также достигло высокого значения 0.9, что указывает на хороший баланс между точностью и полнотой модели.
#
# 4. **Анализ ошибок модели**: Была проведена аналитика ошибок модели, включая построение матрицы ошибок и отчета о классификации на тестовой выборке. Это позволяет лучше понять, в каких случаях модель ошибается и какие классы она предсказывает наиболее точно.
#
# 5. **Precision-Recall кривая**: Была построена кривая precision-recall, которая позволяет оценить производительность модели при различных порогах вероятности классификации. Это дополнительный инструмент для анализа производительности модели и ее применимости в различных сценариях.
#
# Таким образом, на основании проведенного анализа можно утверждать, что логистическая регрессия является наилучшей моделью для классификации клиентов по их покупательской активности в данном наборе данных.

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %% [markdown]
# ### Шаг 7.1. Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP.

# %% [markdown]
# На первой попытке столкнулись с проблемой, так как объект SHAP explainer не может обработать модель напрямую из нашего конвейера. Ошибка указывает на то, что модель не является вызываемой, что необходимо для анализа SHAP.
#
# Предприняли попытку извлечь базовую модель из конвейера, используя лучшую модель из результатов поиска по сетке. Однако, даже после этого, возникла ошибка, указывающая на то, что модель, вероятно, не совместима с SHAP explainer.
#
# В следующей попытке решили использовать SHAP KernelExplainer вместо SHAP TreeExplainer, чтобы попробовать обойти проблему. Однако, это также привело к ошибке, говорящей о несовместимости модели с SHAP explainer.
#
# Далее, попробовали использовать метод shap.kmeans(data, K), чтобы автоматически сгенерировать фоновые данные на основе кластеров данных. Однако, это требует времени, и возможно, нам придется дождаться результатов. Все же лучше ожидания в 2 часа и поучения ошибки вывода..
#
# P.S. 20 минут ожидания того не стоили 🙃
#
# Последний код, представляет собой еще одну попытку инициализировать SHAP explainer с использованием модели и данных. В этом коде извлекаем имена признаков после их преобразования с помощью метода `get_feature_names_out()`, что должно помочь в точном определении данных. Затем преобразуем данные и инициализируем SHAP explainer с использованием этих данных и модели. Этот подход более явно определяет данные и имена признаков, что, возможно, поможет избежать ошибок, возникающих из-за несоответствия размерностей данных и SHAP значений. И он работает...

# %%
# Получение имен признаков после преобразования
feature_names = grid_search.best_estimator_.named_steps['preprocessor'].get_feature_names_out()

# Преобразование данных
X_train_transformed = pd.DataFrame(grid_search.best_estimator_.named_steps['preprocessor'].transform(X_train),
                                   columns=feature_names)

# Инициализация explainer
explainer = shap.Explainer(grid_search.best_estimator_.named_steps['models'], X_train_transformed)

# Вычисление SHAP значений
shap_values = explainer(X_train_transformed)

# Построение графика важности признаков
shap.summary_plot(shap_values, X_train_transformed, plot_type="bar")

# %%
# Извлекаем значения признаков для первой точки данных
feature_values = X_train_transformed.iloc[0]

# Получим значения SHAP для первой точки данных
shap_values_single = shap_values.values[0]

# Создаем список с комбинациями значений признаков, их вклада в SHAP и названий признаков
feature_shap_pairs = []
for feature_name, feature_value, shap_value in zip(feature_names, feature_values, shap_values_single):
    feature_shap_pairs.append((feature_name, feature_value, shap_value))

# Отсортируем список по абсолютному значению SHAP
feature_shap_pairs.sort(key=lambda x: abs(x[2]), reverse=True)

# Построим график важности признаков с отображением значений
plt.figure(figsize=(10, 6))
for i, (feature_name, feature_value, shap_value) in enumerate(feature_shap_pairs):
    plt.barh(feature_name, shap_value)
    plt.text(shap_value, i, f'{feature_value:.2f}', ha='left', va='center', fontsize=8)

plt.xlabel('SHAP значения')
plt.ylabel('Признак')
plt.title('Важность признаков')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# В ходе анализа важности признаков были преодолены некоторые технические проблемы, связанные с использованием SHAP explainer. Были предприняты различные попытки инициализации SHAP explainer, включая извлечение базовой модели из конвейера, использование SHAP KernelExplainer и генерацию фоновых данных с помощью метода shap.kmeans(data, K). В конечном итоге, удалось успешно инициализировать SHAP explainer и вычислить SHAP значения.

# %% [markdown]
# ### Шаг 7.2. Сделаем выводы о значимости признаков:

# %% [markdown]
# **Выводы о значимости признаков:**
#
# 1. **Малозначимые признаки**: Некоторые признаки, такие как 'ohe__тип_сервиса_премиум', 'ohe__разрешить_сообщать_да' и 'ohe__популярная_категория_Косметика и аксесуары', имеют очень низкую важность (SHAP значения близки к нулю). Это означает, что эти признаки мало влияют на прогнозы модели.
#
# 2. **Наиболее важные признаки**: Признаки, такие как 'num__средний_просмотр_категорий_за_визит', 'ohe__популярная_категория_Мелкая бытовая техника и электроника' и 'num__неоплаченные_продукты_штук_квартал', имеют наибольшую важность. Это означает, что они сильно влияют на прогнозы модели.
#
# **Использование этих наблюдений при моделировании и принятии бизнес-решений:**
#
# 1. **Улучшение модели**: Можно улучшить производительность модели, сосредоточившись на наиболее важных признаках. Например, можно провести более тщательный анализ этих признаков, оптимизировать их преобразование и масштабирование или создать новые признаки на основе них.
#
# 2. **Принятие бизнес-решений**: Важность признаков может помочь в принятии бизнес-решений, указывая на области, которые имеют наибольшее влияние на целевой признак. Например, если 'num__средний_просмотр_категорий_за_визит' является важным признаком, то увеличение числа просмотров категорий за визит может улучшить целевой показатель. Это может быть достигнуто путем улучшения пользовательского интерфейса, оптимизации навигации по сайту или проведения маркетинговых кампаний, направленных на увеличение вовлеченности пользователей.

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %% [markdown]
# ### Шаг 8.1.  Выполним сегментацию покупателей. Используем результаты моделирования и данные о прибыльности покупателей.

# %% [markdown]
# Сегментация покупателей может быть выполнена на основе результатов моделирования и данных о прибыльности покупателей. Мы можем использовать прогнозы модели для определения вероятности покупательской активности каждого клиента и сегментировать клиентов на основе этой вероятности. Кроме того, мы можем учесть данные о прибыльности покупателей, чтобы определить, какие клиенты приносят наибольшую прибыль.

# %%
# Получаем вероятности снижения активности для тестового и тренировочного наборов данных
y_test_proba = grid_search.best_estimator_.predict_proba(X_test)[:, 1]
y_train_proba = grid_search.best_estimator_.predict_proba(X_train)[:, 1]

# Добавляем столбец 'вероятность_снижения' в тестовый и тренировочный наборы данных
X_test_full = X_test.copy()
X_train_full = X_train.copy()
X_test_full['вероятность_снижения'] = y_test_proba
X_train_full['вероятность_снижения'] = y_train_proba

# Объединяем тестовый и тренировочный наборы данных
fin_df = pd.concat([X_train_full, X_test_full])
fin_df = fin_df.merge(money, on='id')

# Построим график рассеяния вероятности снижения активности и прибыли
plt.figure(figsize=(10, 6))
plt.scatter(fin_df['вероятность_снижения'], fin_df['прибыль'], alpha=0.5)
plt.xlabel('Вероятность снижения активности')
plt.ylabel('Прибыль')
plt.title('Сегментация покупателей')
plt.grid(True)
plt.show()

scaler = MinMaxScaler()
fin_df['вероятность_снижения_scaled'] = scaler.fit_transform(fin_df[['вероятность_снижения']])
fin_df['прибыль_scaled'] = scaler.fit_transform(fin_df[['прибыль']])

# Производим сегментацию покупателей
fin_df['сегмент'] = pd.qcut(fin_df['вероятность_снижения_scaled'] + fin_df['прибыль_scaled'],
                            q=4, labels=['low', 'medium', 'high', 'very high'])

# Анализ данных внутри сегмента
segment_data = fin_df.groupby('сегмент').agg({
    'вероятность_снижения': 'mean',
    'прибыль': 'mean',
    'id': 'count'
}).reset_index()

segment_data
# Out:
#      сегмент  вероятность_снижения   прибыль   id
# 0        low              0.077117  3.131605  324
# 1     medium              0.136997  4.247315  324
# 2       high              0.411714  4.326420  324
# 3  very high              0.907286  4.285463  324

# %% [markdown]
# **Вероятность снижения активности:**
#    - **Low:** В среднем вероятность снижения активности составляет 0.077, что очень низко.
#    - **Medium:** В среднем вероятность снижения активности составляет 0.137, что все еще относительно низко.
#    - **High:** В среднем вероятность снижения активности составляет 0.412, что значительно выше.
#    - **Very high:** В среднем вероятность снижения активности составляет 0.907, что крайне высоко.
#
# **Прибыль клиентов:**
#    - Клиенты в сегменте "low" приносят в среднем 3.131 прибыли.
#    - Клиенты в сегменте "medium" приносят в среднем 4.247 прибыли.
#    - Клиенты в сегменте "high" приносят в среднем 4.326 прибыли.
#    - Клиенты в сегменте "very high" приносят в среднем 4.285 прибыли.
#
# **Соотношение вероятности снижения активности и прибыли:**
#    - Сегмент "low" имеет самую низкую вероятность снижения активности и самую низкую среднюю прибыль.
#    - Сегменты "medium", "high" и "very high" имеют примерно одинаковый уровень прибыли, несмотря на значительное различие в вероятности снижения активности. Это говорит о том, что высокая вероятность снижения активности не обязательно связана с более низкой прибылью.
#
# **Выводы:**
#
# 1. **Высокая прибыльность клиентов:**
#    - Клиенты в сегментах "medium", "high" и "very high" приносят наибольшую прибыль. Это говорит о том, что даже клиенты с высокой вероятностью снижения активности могут быть весьма прибыльными.
#
# 2. **Фокус на удержание клиентов:**
#    - Особое внимание следует уделить сегменту "very high", так как эти клиенты имеют очень высокую вероятность снижения активности, но при этом остаются прибыльными. Разработка стратегий для удержания этих клиентов может оказать значительное влияние на общую прибыль компании.
#
# 3. **Низкая вероятность снижения активности:**
#    - Клиенты в сегменте "low" имеют самую низкую вероятность снижения активности, но приносят наименьшую прибыль. Возможно, эти клиенты уже максимально используют продукты компании, и их потенциал для увеличения прибыли ограничен.
#
# 4. **Средняя и высокая вероятность снижения активности:**
#    - Сегменты "medium" и "high" представляют собой баланс между вероятностью снижения активности и уровнем прибыли. Эти клиенты могут быть хорошей целью для программ повышения лояльности и стимулирования активности.

# %% [markdown]
# ### Шаг 8.2. Выберем группу покупателей и предложим, как увеличить её покупательскую активность:
# - Проведем графическое и аналитическое исследование группы покупателей.
# - Сделаем предложения по работе с сегментом для увеличения покупательской активности.

# %% [markdown]
# Для дальнейшего анализа выбран сегмент **'Very high'**.

# %% [markdown]
# Этот выбор обусловлен несколькими ключевыми причинами:
#
# 1. **Высокая прибыльность**: Клиенты в этом сегменте приносят высокую прибыль, что делает их наиболее ценными для бизнеса. Удержание этих клиентов и увеличение их покупательской активности может значительно увеличить общую прибыльность.
#
# 2. **Высокая вероятность снижения активности**: Эти клиенты также имеют очень высокую вероятность снижения активности. Это означает, что без соответствующих мер по удержанию, эти ценные клиенты могут стать менее активными или даже уйти.
#
# 3. **Потенциал для оптимизации**: Поскольку этот сегмент имеет высокую прибыльность, но также и высокую вероятность снижения активности, он представляет собой идеальную возможность для оптимизации. Разработка и внедрение стратегий, направленных на увеличение покупательской активности в этом сегменте, может привести к значительному росту прибыли.

# %%
# Выбираем сегмент с наибольшей вероятностью снижения для более детального анализа
selected_segment = segment_data.loc[segment_data['сегмент'] == 'very high']

# Производим анализ данных внутри выбранного сегмента
selected_customers = fin_df.loc[fin_df['сегмент'] == 'very high']
selected_customers.head()
# Out:
#         id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 4   215718    стандарт                нет                 3.1
# 6   216421     премиум                 да                 4.1
# 21  215420    стандарт                 да                 3.5
# 24  215637    стандарт                 да                 2.4
# 29  215540     премиум                 да                 1.4
#
#     маркет_актив_тек_мес  длительность                  популярная_категория  \
# 4                      5           447                     Домашний текстиль
# 6                      3           302                      Товары для детей
# 21                     5           449                     Домашний текстиль
# 24                     5           553                       Кухонная посуда
# 29                     5           355  Мелкая бытовая техника и электроника
#
#     средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# ...

# %% [markdown]
# Изучим распределения вероятности снижения покупательской активности и прибыльности для выбранного сегмента

# %%
# Выбираем данные для выбранного сегмента
selected_data_vh = fin_df[fin_df['сегмент'] == 'very high']

# Строим гистограмму для вероятности снижения активности
plt.figure(figsize=(10, 6))
sns.histplot(data=selected_data_vh, x='вероятность_снижения', bins=30, kde=True)
plt.title('Распределение вероятности снижения активности')
plt.xlabel('Вероятность снижения активности')
plt.ylabel('Количество клиентов')
plt.grid(True)
plt.show()

# Строим гистограмму для прибыли
plt.figure(figsize=(10, 6))
sns.histplot(data=selected_data_vh, x='прибыль', bins=30, kde=True)
plt.title('Распределение прибыли')
plt.xlabel('Прибыль')
plt.ylabel('Количество клиентов')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вероятность снижения активности**: Гистограмма показывает, что большинство клиентов в этом сегменте имеют высокую вероятность снижения активности. Это подчеркивает необходимость активных мер по удержанию для этого сегмента.
#
# **Прибыль**: Распределение прибыли показывает, что большинство клиентов в этом сегменте приносят среднюю или выше среднего прибыль. Это подтверждает ценность этого сегмента для бизнеса.

# %% [markdown]
# Цель - углубиться в поведение клиентов этого сегмента и выявить возможности для увеличения их покупательской активности и прибыльности. Проведем сравнительный анализ с сегментом “High”, чтобы выявить ключевые различия в поведении клиентов этих двух сегментов. Это позволит лучше понять, что делает клиентов сегмента “High” более прибыльными и активными, и использовать эти знания для разработки стратегий, направленных на улучшение показателей сегмента “very high”

# %%
# Выбираем сегмент 'high'
selected_segment_high = segment_data.loc[segment_data['сегмент'] == 'high']

# Производим анализ данных внутри выбранного сегмента
selected_customers_high = fin_df.loc[fin_df['сегмент'] == 'high']

# Выбираем данные для выбранного сегмента
selected_data_high = fin_df[fin_df['сегмент'] == 'high']

# Строим гистограмму для вероятности снижения активности
plt.figure(figsize=(10, 6))
sns.histplot(data=selected_data_high, x='вероятность_снижения', bins=30, kde=True, color='blue', label='high')
sns.histplot(data=selected_data_vh, x='вероятность_снижения', bins=30, kde=True, color='red', label='very high')
plt.title('Сравнение распределения вероятности снижения активности')
plt.xlabel('Вероятность снижения активности')
plt.ylabel('Количество клиентов')
plt.legend(title='Сегмент')
plt.grid(True)
plt.show()

# Строим гистограмму для прибыли
plt.figure(figsize=(10, 6))
sns.histplot(data=selected_data_high, x='прибыль', bins=30, kde=True, color='blue', label='high')
sns.histplot(data=selected_data_vh, x='прибыль', bins=30, kde=True, color='red', label='very high')
plt.title('Сравнение распределения прибыли')
plt.xlabel('Прибыль')
plt.ylabel('Количество клиентов')
plt.legend(title='Сегмент')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вероятность снижения активности**: Гистограмма показывает, что клиенты в сегменте 'High' имеют в основном низкую вероятность снижения активности, в то время как большинство клиентов в сегменте 'Very High' имеют высокую вероятность снижения активности. Это подчеркивает различия в поведении клиентов в этих двух сегментах и подтверждает необходимость различных стратегий удержания для каждого из них.
#
# **Прибыль**: Распределение прибыли показывает, что большинство клиентов в обоих сегментах приносят среднюю или выше среднего прибыль. Однако распределение прибыли в сегменте 'Very High' немного шире, что указывает на большую вариативность в прибыльности клиентов в этом сегменте.
#
# В целом, эти гистограммы подчеркивают различия между сегментами 'High' и 'Very High' и подтверждают необходимость индивидуализированных стратегий для каждого сегмента. Это может включать в себя различные предложения, программы лояльности и стратегии обслуживания клиентов, в зависимости от вероятности снижения активности и прибыльности каждого сегмента.

# %%
# Анализируем тип сервиса
print("Анализ типа сервиса:")
print("Для сегмента very high:")
print(selected_data_vh['тип_сервиса'].value_counts())
print("\n")
print("Для сегмента high:")
print(selected_data_high['тип_сервиса'].value_counts())
print("\n")

# Визуализация типа сервиса
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(data=selected_data_vh, x='тип_сервиса', palette='pastel')
plt.title('Распределение типа сервиса (very high)')
plt.subplot(1, 2, 2)
sns.countplot(data=selected_data_high, x='тип_сервиса', palette='pastel')
plt.title('Распределение типа сервиса (high)')
plt.tight_layout()
plt.show()
# Out:
# Анализ типа сервиса:
# Для сегмента very high:
# стандарт    205
# премиум     119
# Name: тип_сервиса, dtype: int64
#
#
# Для сегмента high:
# стандарт    228
# премиум      96
# Name: тип_сервиса, dtype: int64

# %% [markdown]
# **Сегмент 'Very High'**: В этом сегменте большинство клиентов (205 из 324) используют стандартный тип сервиса, в то время как остальные (119 из 324) предпочитают премиум сервис.
#
# **Сегмент 'High'**: В этом сегменте также большинство клиентов (228 из 324) используют стандартный тип сервиса, но доля клиентов, использующих премиум сервис, немного меньше (96 из 324).
#
# Эти данные могут быть полезны при разработке стратегий для каждого сегмента. Например, для клиентов, использующих стандартный сервис, можно предложить специальные акции или скидки на премиум сервис. Это может помочь увеличить их покупательскую активность и прибыльность.

# %%
# Анализируем длительность
print("Анализ длительности:")
print("Для сегмента very high:")
print(selected_data_vh['длительность'].describe())
print("\n")
print("Для сегмента high:")
print(selected_data_high['длительность'].describe())
print("\n")

# Визуализация длительности
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=selected_data_vh, x='длительность', bins=30, kde=True, color='red')
plt.title('Распределение длительности (very high)')
plt.subplot(1, 2, 2)
sns.histplot(data=selected_data_high, x='длительность', bins=30, kde=True, color='blue')
plt.title('Распределение длительности (high)')
plt.tight_layout()
plt.show()
# Out:
# Анализ длительности:
# Для сегмента very high:
# count     324.000000
# mean      626.382716
# std       233.410682
# min       152.000000
# 25%       449.000000
# 50%       657.000000
# 75%       808.500000
# max      1076.000000
# Name: длительность, dtype: float64
#
#
# Для сегмента high:
# count     324.000000
# mean      631.796296
# std       249.546775
# min       129.000000
# 25%       451.750000
# 50%       638.000000
# 75%       846.000000
# max      1079.000000
# Name: длительность, dtype: float64

# %% [markdown]
# Для сегмента "Very High":
# - Средняя длительность для этого сегмента составляет примерно 626, с минимальной длительностью 152 и максимальной - 1076. Это указывает на то, что клиенты в этом сегменте обычно остаются активными в течение длительного периода времени.
#
# Для сегмента "High":
# - Средняя длительность для этого сегмента немного больше и составляет примерно 632, с минимальной длительностью 129 и максимальной - 1079. Это также указывает на высокую степень активности клиентов в этом сегменте.

# %%
# Анализируем популярную категорию
print("Анализ популярной категории:")
print("Для сегмента very high:")
print(selected_data_vh['популярная_категория'].value_counts())
print("\n")
print("Для сегмента high:")
print(selected_data_high['популярная_категория'].value_counts())
print("\n")

# Визуализация популярной категории
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(data=selected_data_vh, y='популярная_категория', palette='husl')
plt.title('Распределение популярных категорий (very high)')
plt.subplot(1, 2, 2)
sns.countplot(data=selected_data_high, y='популярная_категория', palette='husl')
plt.title('Распределение популярных категорий (high)')
plt.tight_layout()
plt.show()
# Out:
# Анализ популярной категории:
# Для сегмента very high:
# Товары для детей                        102
# Косметика и аксесуары                    70
# Домашний текстиль                        67
# Кухонная посуда                          50
# Техника для красоты и здоровья           23
# Мелкая бытовая техника и электроника     12
# Name: популярная_категория, dtype: int64
#
#
# Для сегмента high:
# Товары для детей                        83
# Косметика и аксесуары                   65
# Домашний текстиль                       65
# Техника для красоты и здоровья          42
# Кухонная посуда                         41
# Мелкая бытовая техника и электроника    28
# Name: популярная_категория, dtype: int64

# %% [markdown]
# Сегмент ‘Very High’: В этом сегменте наиболее популярной категорией являются “Товары для детей” (102 из 324), за которой следуют “Косметика и аксесуары” (70 из 324) и “Домашний текстиль” (67 из 324).
#
# Сегмент ‘High’: В этом сегменте также наиболее популярной категорией являются “Товары для детей” (83 из 324), но “Косметика и аксесуары” и “Домашний текстиль” имеют одинаковую популярность (65 из 324).
#
# - Можно использовать данные о покупках и поведении клиентов, чтобы предлагать им персонализированные товары и акции.
# - Это может повысить заинтересованность клиентов и побудить их к совершению покупок.

# %%
# Анализируем средний просмотр категорий за визит
print("Анализ среднего просмотра категорий за визит:")
print("Для сегмента very high:")
print(selected_data_vh['средний_просмотр_категорий_за_визит'].describe())
print("\n")
print("Для сегмента high:")
print(selected_data_high['средний_просмотр_категорий_за_визит'].describe())
print("\n")

# Визуализация среднего просмотра категорий за визит
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=selected_data_vh, x='средний_просмотр_категорий_за_визит', bins=30, kde=True, color='red')
plt.title('Распределение среднего просмотра категорий за визит (very high)')
plt.subplot(1, 2, 2)
sns.histplot(data=selected_data_high, x='средний_просмотр_категорий_за_визит', bins=30, kde=True, color='blue')
plt.title('Распределение среднего просмотра категорий за визит (high)')
plt.tight_layout()
plt.show()
# Out:
# Анализ среднего просмотра категорий за визит:
# Для сегмента very high:
# count    324.000000
# mean       2.376543
# std        1.064574
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: средний_просмотр_категорий_за_визит, dtype: float64
#
#
# Для сегмента high:
# count    324.000000
# mean       3.092593
# std        1.311089
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        6.000000
# Name: средний_просмотр_категорий_за_визит, dtype: float64

# %% [markdown]
# Из анализа видно, что средний просмотр категорий за визит в сегменте "very high" меньше, чем в сегменте "high" (2.38 против 3.09 соответственно). Это указывает на то, что клиенты из сегмента "high" склонны исследовать больше категорий во время своих визитов, чем клиенты из сегмента "very high".
#
# Чтобы улучшить покупательскую активность в сегменте "very high", можно предложить следующие меры:
#
# **Реализация персонализированных рекомендаций**: Это может стимулировать клиентов исследовать больше категорий, увеличивая их вовлеченность и время, проведенное на сайте.
#
# **Улучшение дизайна пользовательского интерфейса**: Создание более интуитивного и привлекательного дизайна может облегчить навигацию между категориями и сделать процесс более интересным для клиентов.
#
# **Введение стимулов для исследования дополнительных категорий**: Можно предложить скидки или бонусные баллы за просмотр дополнительных категорий. Это может мотивировать клиентов исследовать больше категорий во время каждого визита.

# %%
# Анализируем отношение покупателей выбранного сегмента к рассылкам
print("Отношение покупателей к рассылкам")
print("Для сегмента very high:")
print(selected_data_vh['разрешить_сообщать'].describe())
print("\n")
print("Для сегмента high:")
print(selected_data_high['разрешить_сообщать'].describe())
print("\n")

# Посмотрим на отношение покупателей выбранного сегмента к рассылкам
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='разрешить_сообщать', data=selected_data_vh, palette='Set2')
plt.title('Отношение покупателей к рассылкам (very high)')
plt.xlabel('Разрешить сообщать')
plt.ylabel('Количество покупателей')
plt.subplot(1, 2, 2)
sns.countplot(x='разрешить_сообщать', data=selected_data_high, palette='Set2')
plt.title('Отношение покупателей к рассылкам (high)')
plt.xlabel('Разрешить сообщать')
plt.ylabel('Количество покупателей')
plt.tight_layout()
plt.show()
# Out:
# Отношение покупателей к рассылкам
# Для сегмента very high:
# count     324
# unique      2
# top        да
# freq      240
# Name: разрешить_сообщать, dtype: object
#
#
# Для сегмента high:
# count     324
# unique      2
# top        да
# freq      249
# Name: разрешить_сообщать, dtype: object

# %% [markdown]
# Большинство клиентов в обоих сегментах открыты для коммуникации и рассылки сообщений от компании. Это предоставляет нам возможность использовать этот канал для увеличения вовлеченности клиентов, предоставления им информации о новых продуктах или услугах, акциях и специальных предложениях.
#
# Однако, несмотря на высокую готовность покупателей получать рассылки, важно убедиться, что эти рассылки действительно полезны и интересны для покупателей. Вот несколько предложений по улучшению эффективности рассылок:
#
# **Персонализация рассылок**: Рассылки должны быть максимально адаптированы под интересы каждого конкретного покупателя. Это может включать в себя рекомендации товаров, основанные на истории покупок и просмотров, а также информацию о новинках и акциях в интересующих покупателя категориях.
#
# **Регулярное обновление контента**: Чтобы поддерживать интерес покупателей, важно регулярно обновлять контент рассылок. Это может включать в себя информацию о новых товарах, акциях, сезонных предложениях и т.д.

# %%
# Анализируем распределение долей акционных покупок
print("Анализ распределение долей акционных покупок:")
print("Для сегмента very high:")
print(selected_data_vh['акционные_покупки_категория'].describe())
print("\n")
print("Для сегмента high:")
print(selected_data_high['акционные_покупки_категория'].describe())
print("\n")

# Изучим в выбранном сегменте распределение долей акционных покупок
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='акционные_покупки_категория', data=selected_data_vh, palette='Set3')
plt.title('Распределение долей акционных покупок (very high)')
plt.xlabel('Акционные покупки категория')
plt.ylabel('Количество покупателей')
plt.subplot(1, 2, 2)
sns.countplot(x='акционные_покупки_категория', data=selected_data_high, palette='Set3')
plt.title('Распределение долей акционных покупок (high)')
plt.xlabel('Акционные покупки категория')
plt.ylabel('Количество покупателей')
plt.tight_layout()
plt.show()
# Out:
# Анализ распределение долей акционных покупок:
# Для сегмента very high:
# count                         324
# unique                          2
# top       Редко покупает по акции
# freq                          208
# Name: акционные_покупки_категория, dtype: object
#
#
# Для сегмента high:
# count                         324
# unique                          2
# top       Редко покупает по акции
# freq                          290
# Name: акционные_покупки_категория, dtype: object

# %% [markdown]
# Из анализа видно, что большинство покупателей в обоих сегментах ("very high" и "high") редко покупают по акции. В сегменте "very high" 208 из 324 покупателей редко покупают по акции, в то время как в сегменте "high" таких покупателей больше - 290 из 324.
#
# Это указывает на то, что акционные предложения могут не быть основным фактором, влияющим на покупательскую активность в этих сегментах. Однако, это не исключает возможности использования акций как инструмента для стимулирования покупательской активности. Вот несколько предложений по улучшению эффективности акционных предложений:
#
# **Целевые акции**: Разработайте акции, которые были бы максимально адаптированы под интересы каждого конкретного покупателя. Это может включать в себя акционные предложения на товары, которые покупатель уже просматривал или покупал в прошлом.
#
# **Сезонные акции**: Сезонные акции могут быть эффективным способом стимулирования покупательской активности. Это может включать в себя акции, связанные с праздниками, сменой сезонов и т.д.
#
# **А/Б тестирование**: Проводите А/Б тестирование различных акционных предложений, чтобы определить, что работает лучше всего для вашей аудитории.

# %%
# Анализируем неоплаченные продукты за квартал
print("Анализ неоплаченных продуктов за квартал:")
print("Для сегмента very high:")
print(selected_data_vh['неоплаченные_продукты_штук_квартал'].describe())
print("\n")
print("Для сегмента high:")
print(selected_data_high['неоплаченные_продукты_штук_квартал'].describe())
print("\n")

# Визуализация неоплаченных продуктов за квартал
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=selected_data_vh, x='неоплаченные_продукты_штук_квартал', bins=30, kde=True, color='red')
plt.title('Распределение неоплаченных продуктов за квартал (very high)')
plt.subplot(1, 2, 2)
sns.histplot(data=selected_data_high, x='неоплаченные_продукты_штук_квартал', bins=30, kde=True, color='blue')
plt.title('Распределение неоплаченных продуктов за квартал (high)')
plt.tight_layout()
plt.show()
# Out:
# Анализ неоплаченных продуктов за квартал:
# Для сегмента very high:
# count    324.000000
# mean       4.259259
# std        2.242443
# min        0.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64
#
#
# Для сегмента high:
# count    324.000000
# mean       2.811728
# std        1.874974
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        4.000000
# max       10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64

# %% [markdown]
# Из анализа видно, что в сегменте "very high" среднее количество неоплаченных продуктов за квартал составляет 4.26, в то время как в сегменте "high" это значение меньше и составляет 2.81.
#
# Это может указывать на то, что покупатели из сегмента "very high" чаще добавляют товары в корзину, но не оплачивают их. Это может быть связано с различными факторами, такими как ценообразование, доступность товара, удобство процесса оплаты и т.д.
#
# Вот несколько предложений по улучшению ситуации:
#
# **Улучшение процесса оплаты**: Упрощение процесса оплаты может помочь уменьшить количество неоплаченных товаров. Это может включать в себя уменьшение количества шагов при оформлении заказа, предоставление различных способов оплаты и т.д.
#
# **Ремаркетинг**: Ремаркетинг может быть эффективным способом напомнить покупателям о товарах, которые они добавили в корзину, но не оплатили. Это может включать в себя отправку электронных писем или показ рекламы с этими товарами.
#
# **Анализ поведения покупателей**: Анализ поведения покупателей может помочь понять, почему они не оплачивают товары. Это может включать в себя анализ данных о том, какие товары чаще всего остаются неоплаченными, в какое время суток покупатели чаще всего оставляют товары без оплаты и т.д.

# %%
# Анализируем ошибки сервиса
print("Анализ ошибок сервиса:")
print("Для сегмента very high:")
print(selected_data_vh['ошибка_сервиса'].describe())
print("\n")
print("Для сегмента high:")
print(selected_data_high['ошибка_сервиса'].describe())
print("\n")

# Визуализация ошибок сервиса
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=selected_data_vh, x='ошибка_сервиса', bins=30, kde=True, color='red')
plt.title('Распределение ошибок сервиса (very high)')
plt.subplot(1, 2, 2)
sns.histplot(data=selected_data_high, x='ошибка_сервиса', bins=30, kde=True, color='blue')
plt.title('Распределение ошибок сервиса (high)')
plt.tight_layout()
plt.show()
# Out:
# Анализ ошибок сервиса:
# Для сегмента very high:
# count    324.000000
# mean       3.876543
# std        1.953850
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        9.000000
# Name: ошибка_сервиса, dtype: float64
#
#
# Для сегмента high:
# count    324.000000
# mean       4.067901
# std        1.959739
# min        0.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        9.000000
# Name: ошибка_сервиса, dtype: float64

# %% [markdown]
# Из анализа видно, что в сегменте "very high" среднее количество ошибок сервиса за квартал составляет 3.88, в то время как в сегменте "high" это значение немного выше и составляет 4.07.
#
# Это может указывать на то, что покупатели из сегмента "high" сталкиваются с ошибками сервиса чаще, чем покупатели из сегмента "very high". Это может быть связано с различными факторами, такими как сложность использования сервиса, наличие технических проблем и т.д.
#
# Вот несколько предложений по улучшению ситуации:
#
# **Улучшение пользовательского интерфейса**: Упрощение пользовательского интерфейса может помочь уменьшить количество ошибок сервиса. Это может включать в себя улучшение навигации, упрощение процесса оформления заказа и т.д.
#
# **Техническая поддержка**: Предоставление эффективной технической поддержки может помочь покупателям быстро решить возникающие проблемы и уменьшить количество ошибок сервиса.
#
# **Обратная связь от пользователей**: Сбор обратной связи от пользователей может помочь выявить наиболее частые ошибки сервиса и разработать меры по их устранению.

# %% [markdown]
# ### Шаг 8.3. Сделаем выводы о сегментах:

# %% [markdown]
# **Выбор группы:**
#
# На основе проведенного анализа был выбран сегмент **"Very High"**.
#
# * **Высокая прибыльность:** Клиенты в этом сегменте приносят компании наибольшую прибыль, делая их наиболее ценными.
# * **Высокая вероятность снижения активности:** Эти клиенты также имеют очень высокую вероятность снижения активности, что означает, что без соответствующих мер по удержанию они могут стать менее активными или даже уйти.
# * **Потенциал для оптимизации:** Сочетание высокой прибыльности и высокой вероятности снижения активности делает этот сегмент идеальной возможностью для оптимизации.
#
# **Предложения по увеличению покупательской активности:**
#
# * **Персонализированные рекомендации:** Рекомендовать товары, основанные на истории покупок и просмотров, а также новинки и акции в интересующих покупателя категориях.
# * **Улучшение дизайна пользовательского интерфейса:** Сделать дизайн более интуитивным и привлекательным, чтобы облегчить навигацию между категориями и сделать процесс более интересным.
# * **Стимулы для исследования дополнительных категорий:** Предложить скидки или бонусные баллы за просмотр дополнительных категорий.
# * **Персонализированные рассылки:** Отправлять рассылки, максимально адаптированные под интересы каждого конкретного покупателя, с информацией о новых товарах, акциях и предложениях.
# * **Целевые акции:** Разрабатывать акции, которые были бы максимально адаптированы под интересы каждого конкретного покупателя.
# * **Сезонные акции:** Проводить сезонные акции, связанные с праздниками, сменой сезонов и т.д.
# * **А/Б тестирование:** Проводить А/Б тестирование различных акционных предложений, чтобы определить, что работает лучше всего для вашей аудитории.
# * **Улучшение процесса оплаты:** Упростить процесс оплаты, чтобы уменьшить количество неоплаченных товаров.
# * **Ремаркетинг:** Напоминать покупателям о товарах, которые они добавили в корзину, но не оплатили, с помощью электронных писем или рекламы.
# * **Анализ поведения покупателей:** Проанализировать данные о том, какие товары чаще всего остаются неоплаченными, в какое время суток покупатели чаще всего оставляют товары без оплаты и т.д., чтобы понять причины и принять меры.
#
# **Важно:**
#
# * **Регулярно отслеживать результаты:** Необходимо отслеживать влияние реализованных мер на покупательскую активность и прибыльность, чтобы при необходимости корректировать стратегию.
# * **Обеспечивать персонализированный подход:** Все предложения должны быть максимально адаптированы под интересы каждого конкретного покупателя.
# * **Использовать данные:** Анализ данных о покупателях и их поведении может помочь в разработке наиболее эффективных стратегий удержания и стимулирования покупательской активности.
#
# **Внедрение этих предложений может помочь повысить покупательскую активность и прибыльность в сегменте "Very High", а также укрепить лояльность клиентов к компании.**

# %% [markdown]
# ## Шаг 9. Общий вывод

# %% [markdown]
# **Задача проекта** была в разработке модели, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца для интернет-магазина «В один клик». Целью было увеличить покупательскую активность постоянных клиентов с помощью персонализированных предложений.
#
# **Исходные данные и предобработка**: Данные были успешно загружены из четырех CSV-файлов и проверены на корректность. Была выполнена проверка на дубликаты, пропущенные значения, уникальные значения в категориальных столбцах, а также была проведена проверка целостности данных.
#
# **Поиск лучшей модели**: Было проведено сравнение нескольких моделей машинного обучения, включая Decision Tree, K-Nearest Neighbors, Logistic Regression и Support Vector Classifier. Использовался процесс подбора оптимальных гиперпараметров для каждой модели с помощью GridSearchCV.
#
# **Лучшая модель**: Наилучшей моделью, оцененной с помощью метрики ROC-AUC на тренировочной выборке, оказалась логистическая регрессия (Logistic Regression). Это означает, что логистическая регрессия имеет наилучшую способность разделять классы на тренировочных данных, что является важным показателем для эффективной классификации клиентов по их покупательской активности.
#
# **Оценка производительности**: Выбранная модель была оценена на тестовой выборке с использованием метрик ROC-AUC и F1-score. ROC-AUC показало значение 0.91, что свидетельствует о хорошем качестве модели в разделении классов. F1-score также достигло высокого значения 0.9, что указывает на хороший баланс между точностью и полнотой модели.
#
# **Анализ ошибок модели**: Была проведена аналитика ошибок модели, включая построение матрицы ошибок и отчета о классификации на тестовой выборке. Это позволяет лучше понять, в каких случаях модель ошибается и какие классы она предсказывает наиболее точно.
#
# **Precision-Recall кривая**: Была построена кривая precision-recall, которая позволяет оценить производительность модели при различных порогах вероятности классификации. Это дополнительный инструмент для анализа производительности модели и ее применимости в различных сценариях.
#
# Таким образом, на основании проведенного анализа можно утверждать, что логистическая регрессия является наилучшей моделью для классификации клиентов по их покупательской активности в данном наборе данных.
#
# **Сегментация покупателей**:Проведенная сегментация рынка позволила выделить **4** основных сегмента покупателей:
#
# * **"Very High"**:
#     * **Описание:** Покупатели, которые совершают покупки чаще всего и тратят больше всего денег.
#     * **Характеристика:**
#         * **Высокая ценность:**  Эти покупатели приносят компании наибольшую прибыль.
#         * **Высокая вероятность снижения активности:**  Существует риск, что они могут стать менее активными или даже уйти.
#         * **Потенциал для оптимизации:**  Это идеальная группа для оптимизации за счет персонализации и стимулирования.
#
# * **"High"**:
#     * **Описание:** Покупатели, которые совершают покупки часто и тратят много денег.
#     * **Характеристика:**
#         * **Ценные:**  Эти покупатели также приносят компании значительную прибыль.
#         * **Средняя вероятность снижения активности:**  Они с меньшей вероятностью, чем "Very High", станут менее активными, но все же требуют внимания.
#
# * **"Medium"**:
#     * **Описание:** Покупатели, которые совершают покупки с умеренной частотой и тратят средние суммы.
#     * **Характеристика:**
#         * **Потенциально ценные:**  При правильном подходе эти покупатели могут стать более активными и прибыльными.
#         * **Средняя вероятность снижения активности:**  Они с такой же вероятностью могут стать менее активными, как и повысить свою активность.
#
# * **"Low"**:
#     * **Описание:** Покупатели, которые совершают покупки редко и тратят мало денег.
#     * **Характеристика:**
#         * **Низкая ценность:**  Эти покупатели приносят компании наименьшую прибыль.
#         * **Низкая вероятность снижения активности:**  Существует высокий риск, что они могут стать менее активными или даже уйти.
#
# **Дополнительные предложения:**
#
# * **Программа лояльности:**  Разработать программу лояльности, которая будет вознаграждать клиентов за их активность и стимулировать их совершать больше покупок.
# * **VIP-статус:**  Предложить VIP-статус для самых ценных клиентов, который будет предоставлять им дополнительные преимущества, такие как эксклюзивные скидки, ранний доступ к новым товарам и услуги персонального обслуживания.
# * **Обратная связь:**  Регулярно запрашивать обратную связь от клиентов, чтобы понять их потребности и ожидания и улучшить качество обслуживания.
#
# **Внедрение этих дополнительных предложений может помочь еще больше повысить покупательскую активность и прибыльность в сегменте "Very High", а также сделать клиентов более лояльными к компании.**
#
# **Важно:**
#
# * **Необходимо постоянно отслеживать результаты** реализованных мер и корректировать стратегию при необходимости.
# * **Все предложения должны быть максимально персонализированы** под интересы каждого конкретного покупателя.
# * **Анализ данных о покупателях и их поведении**  поможет в разработке наиболее эффективных стратегий удержания и стимулирования покупательской активности.
#
# В целом, проект был успешным и позволил создать модель, которая может прогнозировать вероятность снижения покупательской активности клиентов интернет-магазина "В один клик". Результаты проекта могут быть использованы для разработки эффективных маркетинговых стратегий, направленных на удержание клиентов и повышение их лояльности.
